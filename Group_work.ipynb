# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# read aigburth #omit
dfaig = pd.read_csv('/home/aigburth station.csv',sep=';')
dfaig
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5   PM10
# 0     2021-11-01 13:22:06        23.98     41.40   1.64   3.81   6.81
# 1     2021-11-02 17:50:12        16.46     56.53   2.51   4.58   8.38
# 2     2021-11-02 17:51:50        16.86     55.36   2.28   3.90   8.09
# 3     2021-11-03 09:00:59        14.94     59.04 280.46 342.70 344.99
# 4     2021-11-03 10:00:51        13.77     59.73 279.75 342.01 344.31
# ...                   ...          ...       ...    ...    ...    ...
# 8443  2022-04-27 21:35:54         6.65     54.93   4.57  14.49  44.15
# 8444  2022-04-27 22:05:53         6.20     55.54   6.59  19.09  70.63
# 8445  2022-04-27 22:35:45         5.86     55.99   7.58  18.84  43.43
# 8446  2022-04-27 23:05:42         5.68     56.40   8.60  20.73  78.38
# 8447  2022-04-27 23:35:34         5.23     56.92  10.34  23.34  64.56
#
# [8448 rows x 6 columns]

# %%
dfaig.drop([2327, 2328, 2525, 2536, 2549, 2556, 2561, 2565, 2566, 2570, 2571, 2574, 2577, 2581, 2585, 2594, 2600, 2605, 2607, 2609, 2611, 2612, 2614, 2615, 2621, 2626, 2627, 2631, 2632, 2633, 2636, 2637, 2640, 2642, 2648, 2650, 2654, 2656, 2657, 2661, 2665, 2666, 2671, 2674, 2678, 2679, 2680, 2682, 2685, 2689, 2690, 2691, 2692, 2701, 2702, 2704, 2705, 2706, 2709, 2712, 2714, 2715, 2719, 2720, 2734, 2739, 2740, 2747, 2762, 2764, 2772, 2781, 2786, 2794, 2798, 2800, 2802, 2815, 2819, 2826, 2845, 2847, 2848, 2850, 2855, 2866, 2867, 2873, 2874, 2883, 2884, 2890, 2895, 2914, 2966], inplace = True)

# %%
datesaig = dfaig['Date & Time']
datesaig = pd.DatetimeIndex(datesaig)
pm2p5aig = dfaig['PM2.5']
tempaig = dfaig['Temperature']
pm10aig = dfaig['PM10']
meanpm2p5aig=np.mean(pm2p5aig)
print(meanpm2p5aig)
plt.plot(datesaig,pm2p5aig, 'red')
# Out:
# 28.988121553392567

# %%
# read all saints #omit
dfall = pd.read_csv('/home/all saints.csv',sep=';')
dfall
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-03 10:44:56         8.13     96.87   5.37  12.00 81.31
# 1     2021-11-03 11:14:54         9.71     96.31   1.02   1.25  4.61
# 2     2021-11-03 11:44:48        11.16     96.17   0.21   0.28  3.63
# 3     2021-11-03 12:14:45        12.27     96.18   0.18   0.20  3.55
# 4     2021-11-03 12:44:37        13.06     96.26   0.07   0.09  3.44
# ...                   ...          ...       ...    ...    ...   ...
# 6001  2022-04-27 21:40:31         6.60     50.16   2.50   9.36 34.00
# 6002  2022-04-27 22:10:22         6.00     50.80   2.70   9.33 47.68
# 6003  2022-04-27 22:40:30         5.57     51.38   3.29  10.34 39.86
# 6004  2022-04-27 23:10:14         5.07     51.92   4.36  13.15 36.55
# 6005  2022-04-27 23:40:08         4.80     52.59   5.06  12.56 30.53
#
# [6006 rows x 6 columns]

# %%
dfall.drop([1135, 1136], inplace = True)
datesall = dfall['Date & Time']
datesall = pd.DatetimeIndex(datesall)
tempall = dfall['Temperature']
pm10all = dfall['PM10']
pm2p5all = dfall['PM2.5']
plt.plot(datesall,pm2p5all, 'red')

# %%
# read anfield #omit
dfanf = pd.read_csv('/home/anfield.csv',sep=';')
dfanf
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-04 16:52:21        15.60     49.27   0.97   3.23 18.47
# 1     2021-11-05 07:48:54        13.35     59.23   2.40   4.41 11.77
# 2     2021-11-05 08:18:49        13.68     55.40   1.14   1.38  3.62
# 3     2021-11-05 08:48:43        15.34     53.48   2.38   5.12 53.98
# 4     2021-11-09 17:23:46        13.89     74.33   1.07   3.19 24.78
# ...                   ...          ...       ...    ...    ...   ...
# 5024  2022-04-27 21:38:51         6.32     52.85   4.14  13.30 60.68
# 5025  2022-04-27 22:08:44         6.01     53.71   4.60  15.67 66.00
# 5026  2022-04-27 22:38:35         5.57     54.44   6.01  16.79 55.03
# 5027  2022-04-27 23:08:31         5.03     56.12   7.27  18.80 49.99
# 5028  2022-04-27 23:38:24         4.46     57.72   6.21  15.61 60.80
#
# [5029 rows x 6 columns]

# %%
dfanf.drop([904, 1089, 1094, 1108, 1202, 1203, 1232, 2281, 2283, 2285, 3831, 4608, 1433], inplace = True)

# %%
datesanf = dfanf['Date & Time']
datesanf = pd.DatetimeIndex(datesanf)
tempanf = dfanf['Temperature']
pm10anf = dfanf['PM10']
pm2p5anf = dfanf['PM2.5']
plt.plot(datesanf,pm2p5anf, 'red')

# %%
# leaving birkenead till end as is a defra
#read brunswick #ok
dfbru = pd.read_csv('/home/brunswick station.csv',sep=';')
dfbru
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-01 00:20:28         8.10     87.30   1.10   4.87 12.08
# 1     2021-11-01 00:50:21         8.01     87.52   0.73   4.12 12.02
# 2     2021-11-01 01:50:07         8.42     89.72   1.53   8.87 35.48
# 3     2021-11-01 02:20:01         8.63     90.01   1.71   9.85 34.55
# 4     2021-11-01 02:49:53         8.76     89.27   1.62   9.63 26.04
# ...                   ...          ...       ...    ...    ...   ...
# 6834  2022-04-27 20:21:19         8.76     43.91   2.43   8.76 28.58
# 6835  2022-04-27 20:51:11         8.06     44.68   3.01   9.71 27.87
# 6836  2022-04-27 21:21:02         7.43     45.45   3.04  10.77 26.44
# 6837  2022-04-27 22:20:46         6.82     46.74   3.49  10.51 26.49
# 6838  2022-04-27 23:20:32         6.22     48.12   4.34  13.80 38.08
#
# [6839 rows x 6 columns]

# %%
dfbru.drop([13, 33, 34, 37, 38, 41, 45, 47, 48, 49, 51, 53, 54, 55, 56, 57, 78, 82, 83, 84, 85, 87, 119, 128, 129, 132, 133, 134, 134, 144, 150, 153, 155, 156, 158, 161, 163, 167, 317, 320, 321, 423, 424, 425, 475, 476, 478, 479, 480, 485, 532, 592, 647, 651, 656, 584, 691, 692, 694, 704, 706, 709, 719, 721, 749, 751, 773, 797, 853, 863, 869, 878, 916, 918, 922, 927, 928, 934, 949, 952, 964, 965, 997, 1036, 1058, 1060, 1061, 1174, 1200, 1207, 1230, 1301, 1313, 1329, 1400, 1406, 1719], inplace = True)

# %%
#brunswick
datesbru = dfbru['Date & Time']
datesbru = pd.DatetimeIndex(datesbru)
tempbru = dfbru['Temperature']
pm2p5bru = dfbru['PM2.5']
pm10bru = dfbru['PM10']
plt.plot(datesbru,pm2p5bru, 'black')

# %%
#read everton #ok
dfeve = pd.read_csv('/home/everton valley.csv',sep=';')
dfeve
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-04 17:09:02        15.84     50.34   1.15   2.78  9.39
# 1     2021-11-04 17:10:56        16.26     49.36   1.07   2.61 11.58
# 2     2021-11-05 07:55:45        13.91     57.86   2.52   4.98 14.37
# 3     2021-11-05 08:25:42        14.31     55.43   3.24   7.20 19.55
# 4     2021-11-05 11:24:58        11.72     62.23   8.83  19.07 37.72
# ...                   ...          ...       ...    ...    ...   ...
# 6653  2022-04-27 21:27:34         7.53     51.70   6.83  18.36 75.67
# 6654  2022-04-27 21:57:26         7.26     52.77   5.74  17.08 70.78
# 6655  2022-04-27 22:27:18         6.69     53.21   6.86  17.42 55.51
# 6656  2022-04-27 22:57:10         6.35     54.09   7.92  21.27 63.66
# 6657  2022-04-27 23:27:03         5.78     55.42   8.32  20.67 61.72
#
# [6658 rows x 6 columns]

# %%
#sort out titles for each one and get rid of zeros
#everton
dateseve = dfeve['Date & Time']
dateseve = pd.DatetimeIndex(dateseve)
tempeve = dfeve['Temperature']
pm2p5eve = dfeve['PM2.5']
pm10eve = dfeve['PM10']
pm2p5eve[pm2p5eve < 0] = 0
pm10eve[pm10eve < 0] = 0
plt.plot(dateseve,pm2p5eve, 'red')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
#read garston #omit
dfgar = pd.read_csv('/home/garston.csv', sep=';')
dfgar
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-04 17:14:28        15.85     48.11   0.00   0.00  0.00
# 1     2021-11-04 17:15:58        16.19     47.86   0.58   1.67 17.00
# 2     2021-11-04 17:17:32        16.68     51.23   0.55   1.74  9.54
# 3     2021-11-04 17:18:34        16.71     45.74   0.51   1.15  3.22
# 4     2021-11-05 07:58:38        13.68     56.99   1.13   2.34 11.97
# ...                   ...          ...       ...    ...    ...   ...
# 7643  2022-04-27 21:59:49         6.68     53.88   3.00   8.81 21.98
# 7644  2022-04-27 22:30:18         6.31     55.14   2.98   9.24 23.27
# 7645  2022-04-27 22:59:44         6.04     55.62   3.14   8.69 16.06
# 7646  2022-04-27 23:29:36         5.66     56.14   3.00   8.89 29.16
# 7647  2022-04-27 23:59:28         5.11     56.74   3.02   8.56 16.62
#
# [7648 rows x 6 columns]

# %%
dfgar.drop([0, 6, 4743, 4744, 4745, 4746, 4747, 4748, 4749], inplace = True)

# %%
#garston
datesgar = dfgar['Date & Time']
datesgar = pd.DatetimeIndex(datesgar)
tempgar = dfgar['Temperature']
pm2p5gar = dfgar['PM2.5']
pm10gar = dfgar['PM10']
pm2p5gar[pm2p5gar < 0] = 0
pm10gar[pm10gar < 0] = 0
plt.plot(datesgar,pm2p5gar, 'black')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#read kirkdale #ok
dfkir = pd.read_csv('/home/kirkdale station.csv', sep=';')
dfkir
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-01 00:52:37         8.46     86.74   0.88   4.18 12.83
# 1     2021-11-01 01:52:23         8.96     87.10   1.98  13.83 47.39
# 2     2021-11-01 03:22:04         9.20     80.99   1.73  11.03 41.08
# 3     2021-11-01 03:51:56         9.22     79.88   1.06   6.69 18.04
# 4     2021-11-01 05:21:34         9.53     78.08   2.35  13.52 60.39
# ...                   ...          ...       ...    ...    ...   ...
# 5145  2022-04-27 18:38:29        11.38     42.49   2.21   8.03 26.21
# 5146  2022-04-27 20:37:54         8.59     46.94   2.29   8.09 29.54
# 5147  2022-04-27 21:07:45         8.08     47.34   2.51   9.53 30.37
# 5148  2022-04-27 21:37:37         7.59     47.67   2.85   9.78 27.99
# 5149  2022-04-27 22:07:29         7.25     48.79   3.18  10.19 25.95
#
# [5150 rows x 6 columns]

# %%
#kirkdale
dateskir = dfkir['Date & Time']
dateskir = pd.DatetimeIndex(dateskir)
tempkir = dfkir['Temperature']
pm2p5kir = dfkir['PM2.5']
pm10kir = dfkir['PM10']
pm2p5kir[pm2p5kir < 0] = 0
pm10kir[pm10kir < 0] = 0
plt.plot(dateskir,pm2p5kir, 'black')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#read life sciences building #ok
dflif = pd.read_csv('/home/life sciences building.csv', sep=';')
dflif
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-01 00:10:49         7.31    101.25   1.15   4.14 14.31
# 1     2021-11-01 00:40:43         7.10    101.15   0.66   3.03 14.56
# 2     2021-11-01 01:10:36         7.32    101.77   0.78   4.57 15.98
# 3     2021-11-01 01:40:30         7.59    101.58   1.10   5.97 22.92
# 4     2021-11-01 02:10:25         7.94    101.79   1.14   6.63 28.71
# ...                   ...          ...       ...    ...    ...   ...
# 8485  2022-04-27 21:39:39         6.46     46.31   2.67   9.87 36.53
# 8486  2022-04-27 22:09:31         6.06     47.39   3.14  10.52 27.35
# 8487  2022-04-27 22:39:25         5.67     48.16   3.72  11.55 34.08
# 8488  2022-04-27 23:09:19         5.46     49.10   4.56  13.96 40.35
# 8489  2022-04-27 23:39:13         5.35     50.28   4.54  14.22 29.35
#
# [8490 rows x 6 columns]

# %%
#life sciences
dateslif = dflif['Date & Time']
dateslif = pd.DatetimeIndex(dateslif)
templif = dflif['Temperature']
pm2p5lif = dflif['PM2.5']
pm10lif = dflif['PM10']
pm2p5lif[pm2p5lif < 0] = 0
pm10lif[pm10lif < 0] = 0
plt.plot(dateslif,pm2p5lif, 'black')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#read liverpool central #ok
dflpc = pd.read_csv('/home/liverpool central station.csv', sep=';')
dflpc
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-01 00:18:59         7.36     89.09   5.19  13.95 31.01
# 1     2021-11-01 00:48:51         7.28     89.10   3.59  10.09 20.36
# 2     2021-11-01 01:18:45         7.62     89.16   3.22  14.25 33.58
# 3     2021-11-01 01:48:38         7.66     89.50   2.98  14.64 38.26
# 4     2021-11-01 02:18:32         7.91     89.66   2.89  12.74 31.92
# ...                   ...          ...       ...    ...    ...   ...
# 5422  2022-04-27 19:48:31         9.70     43.60   7.24  16.41 42.91
# 5423  2022-04-27 20:48:04         8.23     45.33   8.37  16.55 58.75
# 5424  2022-04-27 21:47:41         7.24     46.77  12.75  21.45 36.26
# 5425  2022-04-27 22:47:19         6.60     48.18  18.30  28.00 55.75
# 5426  2022-04-27 23:46:58         5.88     49.50  26.03  38.86 65.86
#
# [5427 rows x 6 columns]

# %%
#lpool central
dateslpc = dflpc['Date & Time']
dateslpc = pd.DatetimeIndex(dateslpc)
templpc = dflpc['Temperature']
pm2p5lpc = dflpc['PM2.5']
pm10lpc = dflpc['PM10']
plt.plot(dateslpc,pm2p5lpc, 'black')

# %%
#ljmu #omit
dfjmu = pd.read_csv('/home/ljmu henry cotton.csv', sep=';')
dfjmu
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-02 18:17:59        17.08     56.93   1.60   3.65 10.02
# 1     2021-11-02 18:20:24        17.35     57.42   1.68   3.29 13.57
# 2     2021-11-02 18:30:02        17.19     55.81   1.36   2.90 10.06
# 3     2021-11-02 18:55:49        17.21     56.24   1.35   2.63 47.75
# 4     2021-11-03 11:49:57        16.49     60.07   0.59   1.25  2.96
# ...                   ...          ...       ...    ...    ...   ...
# 8804  2022-04-27 21:37:00         6.71     54.69   1.39   4.43 13.01
# 8805  2022-04-27 22:06:51         6.35     56.70   3.28  11.38 26.08
# 8806  2022-04-27 22:36:42         6.00     58.39   4.20  11.92 29.80
# 8807  2022-04-27 23:06:34         5.83     60.80   4.30  12.52 31.97
# 8808  2022-04-27 23:36:26         5.52     62.78   4.06  10.45 26.83
#
# [8809 rows x 6 columns]

# %%
dfjmu.drop([2327, 2331, 2333, 2336, 2339, 5724, 5725, 5726, 5727, 5728], inplace = True)

# %%
#ljmu
datesjmu = dfjmu['Date & Time']
datesjmu = pd.DatetimeIndex(datesjmu)
tempjmu = dfjmu['Temperature']
pm2p5jmu = dfjmu['PM2.5']
pm10jmu = dfjmu['PM10']
plt.plot(datesjmu,pm2p5jmu, 'black')

# %%
#haymarket #omit
dfhay = pd.read_csv('/home/old haymarket.csv', sep=';')
dfhay
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-01 00:28:21         8.20     87.50   1.67   6.74 24.03
# 1     2021-11-01 00:58:13         7.98     87.78   1.21   4.81 14.90
# 2     2021-11-01 01:28:06         8.37     87.83   1.91  10.90 28.54
# 3     2021-11-01 01:57:58         8.51     87.76   2.21  13.63 44.37
# 4     2021-11-01 02:27:50         8.76     87.40   1.82  10.68 39.09
# ...                   ...          ...       ...    ...    ...   ...
# 8948  2022-04-27 21:40:21         7.71     51.27   2.88   9.66 32.70
# 8949  2022-04-27 22:10:12         7.41     51.88   3.51  12.47 49.00
# 8950  2022-04-27 22:40:02         7.04     52.38   4.32  13.52 34.44
# 8951  2022-04-27 23:09:54         6.71     52.97   5.41  14.69 42.07
# 8952  2022-04-27 23:39:45         6.43     53.44   4.86  13.48 41.15
#
# [8953 rows x 6 columns]

# %%
#haymarket
dateshay = dfhay['Date & Time']
dateshay = pd.DatetimeIndex(dateshay)
temphay = dfhay['Temperature']
pm2p5hay = dfhay['PM2.5']
pm10hay = dfhay['PM10']
plt.plot(dateshay,pm2p5hay, 'black')

# %%
#old swan #omit
dfosw = pd.read_csv('/home/old swan.csv', sep=';')
dfosw
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-04 16:58:51        15.68     48.49   1.07   2.55 12.93
# 1     2021-11-04 17:00:41        15.91     47.62   1.14   3.79 19.55
# 2     2021-11-05 07:52:48        13.35     66.25   2.12   3.74  8.56
# 3     2021-11-05 08:22:43        13.78     55.39   2.05   3.88  7.46
# 4     2021-11-05 08:52:40        17.18     52.51   2.58  11.49 43.77
# ...                   ...          ...       ...    ...    ...   ...
# 4483  2022-04-27 16:02:13        15.25     42.03   2.91  10.79 33.45
# 4484  2022-04-27 19:31:08         8.96     46.90   2.99  11.58 29.47
# 4485  2022-04-27 21:00:42         6.48     49.74   3.55  13.80 52.29
# 4486  2022-04-27 22:00:26         5.58     51.33   4.48  14.38 48.32
# 4487  2022-04-27 23:00:10         4.89     52.55   6.89  18.77 49.93
#
# [4488 rows x 6 columns]

# %%
#old swan
datesosw = dfosw['Date & Time']
datesosw = pd.DatetimeIndex(datesosw)
temposw = dfosw['Temperature']
pm2p5osw = dfosw['PM2.5']
pm10osw = dfosw['PM10']
plt.plot(datesosw,pm2p5osw, 'black')

# %%
#queen square #ok
dfqsq = pd.read_csv('/home/queens square.csv', sep=';')
dfqsq
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5   PM10
# 0     2021-11-01 00:22:47         8.67     93.58 109.71 134.11 139.20
# 1     2021-11-01 00:52:33         8.04    101.85  55.48  64.69  69.47
# 2     2021-11-01 01:22:22         8.67    101.01  80.55  99.65 107.68
# 3     2021-11-01 01:52:12         8.58     99.73  76.02  94.69 107.98
# 4     2021-11-01 02:22:01         8.80     95.12 151.05 190.08 204.09
# ...                   ...          ...       ...    ...    ...    ...
# 8418  2022-04-27 21:31:02         8.38     67.69  48.22  58.11  65.22
# 8419  2022-04-27 22:00:51         8.05     69.53  39.24  46.99  59.41
# 8420  2022-04-27 22:30:40         7.66     71.22  52.90  64.37  78.17
# 8421  2022-04-27 23:00:29         7.34     72.87  45.81  55.70  65.21
# 8422  2022-04-27 23:30:17         7.04     73.52  45.64  55.70  70.39
#
# [8423 rows x 6 columns]

# %%
#queen square
datesqsq = dfqsq['Date & Time']
datesqsq= pd.DatetimeIndex(datesqsq)
tempqsq = dfqsq['Temperature']
pm2p5qsq = dfqsq['PM2.5']
pm10qsq = dfqsq['PM10']
plt.plot(datesqsq,pm2p5qsq, 'black')

# %%
#roxby #omit
dfrox = pd.read_csv('/home/roxby building.csv', sep=';')
dfrox
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-01 00:17:29         7.57     95.89   0.90   3.69 10.14
# 1     2021-11-01 00:47:22         7.28     95.78   0.50   2.34  7.16
# 2     2021-11-01 01:17:18         7.62     96.59   0.88   5.03 13.72
# 3     2021-11-01 01:47:13         7.59     96.59   0.99   6.13 25.93
# 4     2021-11-01 02:17:08         7.99     96.57   0.96   5.86 17.91
# ...                   ...          ...       ...    ...    ...   ...
# 8987  2022-04-27 21:57:28         6.48     53.63   3.03  11.22 30.33
# 8988  2022-04-27 22:27:22         6.15     54.60   3.68  10.91 22.48
# 8989  2022-04-27 22:57:17         5.85     55.50   4.21  13.67 29.75
# 8990  2022-04-27 23:27:11         5.53     56.68   4.62  12.77 28.30
# 8991  2022-04-27 23:57:06         5.18     57.48   6.54  16.19 37.43
#
# [8992 rows x 6 columns]

# %%
dfrox.drop([2267, 2287, 5780, 5785], inplace = True)

# %%
#roxby
datesrox = dfrox['Date & Time']
datesrox= pd.DatetimeIndex(datesrox)
temprox = dfrox['Temperature']
pm2p5rox = dfrox['PM2.5']
pm10rox = dfrox['PM10']
plt.plot(datesrox,pm2p5rox, 'black')

# %%
# left speke and st helens till end because it is defra, St Mikes was shit so got rid and never did iyt
#st nic #omit
dfnic = pd.read_csv('/home/st nicolas.csv', sep=';')
dfnic
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-01 00:16:46         7.15    188.70   1.26   5.01 15.55
# 1     2021-11-01 00:46:36         6.94    188.18   1.02   3.80 11.93
# 2     2021-11-01 01:16:29         7.34    188.42   1.59   7.96 28.52
# 3     2021-11-01 01:46:21         7.43    186.94   1.90   9.76 31.10
# 4     2021-11-01 02:16:10         7.64    186.35   1.97   9.75 28.40
# ...                   ...          ...       ...    ...    ...   ...
# 9003  2022-04-27 21:56:31         6.50     55.18   2.35   8.18 23.49
# 9004  2022-04-27 22:26:20         6.20     55.98   2.82   9.01 18.88
# 9005  2022-04-27 22:56:11         5.83     56.56   3.03  10.07 28.09
# 9006  2022-04-27 23:26:01         5.48     57.26   0.04   0.08  1.76
# 9007  2022-04-27 23:55:51         5.16     57.71   3.64   9.53 29.05
#
# [9008 rows x 6 columns]

# %%
dfnic.drop([7316], inplace = True)

# %%
#st nic
datesnic = dfnic['Date & Time']
datesnic= pd.DatetimeIndex(datesnic)
tempnic = dfnic['Temperature']
pm2p5nic = dfnic['PM2.5']
pm10nic = dfnic['PM10']
plt.plot(datesnic,pm2p5nic, 'black')

# %%
#strand albert dock #ok
dfsad = pd.read_csv('/home/strand albert dock.csv', sep=';')
dfsad
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5   PM10
# 0     2021-11-01 00:14:12        10.18     10.65   6.64  28.12 100.46
# 1     2021-11-01 00:35:49         9.55     20.88   4.64  23.30  98.84
# 2     2021-11-01 00:57:26         9.44     42.19   5.45  28.10  50.08
# 3     2021-11-01 01:19:03         9.83     36.54   5.94  28.81  67.32
# 4     2021-11-01 01:40:41         9.85     34.85   7.42  39.89  73.05
# ...                   ...          ...       ...    ...    ...    ...
# 9966  2022-04-27 21:43:12         9.12     96.09  10.39  33.63  52.07
# 9967  2022-04-27 22:15:37         8.78     96.82  11.68  43.40 101.01
# 9968  2022-04-27 22:48:03         8.40     98.50  13.52  45.91 109.97
# 9969  2022-04-27 23:20:29         8.10    100.34  17.04  54.93 106.50
# 9970  2022-04-27 23:52:57         7.66    102.03  18.09  54.46 115.02
#
# [9971 rows x 6 columns]

# %%
#strand albert dock
datessad = dfsad['Date & Time']
datessad= pd.DatetimeIndex(datessad)
tempsad = dfsad['Temperature']
pm2p5sad = dfsad['PM2.5']
pm10sad = dfsad['PM10']
plt.plot(datessad,pm2p5sad, 'black')

# %%
#strand chavasse #ok
dfscp = pd.read_csv('/home/strand chavasse park.csv', sep=';')
dfscp
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5   PM10
# 0     2021-11-01 00:04:31        10.29     26.60   7.47  41.85 101.33
# 1     2021-11-01 00:26:37         9.91     27.61   5.23  33.05 145.87
# 2     2021-11-01 00:48:44         9.18     36.67   4.39  27.99  62.52
# 3     2021-11-01 01:10:50         9.78     35.52   6.45  37.67  93.68
# 4     2021-11-01 01:32:57         9.78     36.01   7.42  45.11 103.28
# ...                   ...          ...       ...    ...    ...    ...
# 9838  2022-04-27 21:41:24         9.10    108.24   6.99  35.35  98.54
# 9839  2022-04-27 22:14:35         8.73    109.05   7.71  39.00 125.18
# 9840  2022-04-27 22:47:45         8.38    111.45   8.50  42.10 101.83
# 9841  2022-04-27 23:20:56         8.06    114.41   8.14  39.23  96.34
# 9842  2022-04-27 23:54:08         7.62    117.85  10.64  46.37  94.45
#
# [9843 rows x 6 columns]

# %%
#strand chavasse
# had ridiculously high values over 20000 so used code to bring it down
datesscp = dfscp['Date & Time']
datesscp= pd.DatetimeIndex(datesscp)
tempscp = dfscp['Temperature']
pm2p5scp = dfscp['PM2.5']
pm10scp = dfscp['PM10']
plt.plot(datesscp,pm2p5scp, 'black')
pm2p5scp[pm2p5scp > 2000] = 100
pm10scp[pm10scp > 2000] = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
#uol maths #ok
dfuol = pd.read_csv('/home/uol maths building.csv', sep=';')
dfuol
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-01 00:09:40         8.06    106.52   2.04   7.91 17.51
# 1     2021-11-01 00:39:34         7.57    113.05   1.16   5.98 20.20
# 2     2021-11-01 01:09:24         7.82    114.60   1.31   5.70 14.54
# 3     2021-11-01 01:39:14         7.93    113.84   2.25  11.19 34.43
# 4     2021-11-01 02:09:08         8.44    107.16   2.21  11.88 25.19
# ...                   ...          ...       ...    ...    ...   ...
# 8366  2022-04-26 09:14:04       -40.00     64.03  13.83  22.25 42.20
# 8367  2022-04-26 09:43:56       -40.00     59.53  11.56  19.94 34.27
# 8368  2022-04-26 10:13:45       -40.00     58.97  11.87  20.03 35.27
# 8369  2022-04-26 10:43:45       -40.00     51.74   9.80  17.49 64.71
# 8370  2022-04-26 11:13:36       -40.00     57.97   3.25   7.00 18.53
#
# [8371 rows x 6 columns]

# %%
#uol maths
datesuol = dfuol['Date & Time']
datesuol= pd.DatetimeIndex(datesuol)
tempuol = dfuol['Temperature']
pm2p5uol = dfuol['PM2.5']
pm10uol = dfuol['PM10']
plt.plot(datesuol,pm2p5uol, 'black')

# %%
#wavertree reloved #ok
dfwav = pd.read_csv('/home/wavertree reloved.csv', sep=';')
dfwav
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-01 00:03:59         7.27     99.00   0.82   3.14  7.74
# 1     2021-11-01 00:33:54         7.30     99.43   0.80   2.68  7.17
# 2     2021-11-01 01:03:49         7.41     99.49   0.43   1.39  4.96
# 3     2021-11-01 01:33:45         7.71     99.21   0.90   5.17 23.93
# 4     2021-11-01 02:03:41         7.82     99.22   0.99   5.64 15.49
# ...                   ...          ...       ...    ...    ...   ...
# 7306  2022-04-27 21:44:05         7.77     47.34   2.97   9.39 24.07
# 7307  2022-04-27 22:13:58         7.40     47.89   2.72   8.60 28.81
# 7308  2022-04-27 22:43:52         6.95     48.54   3.66   9.84 17.07
# 7309  2022-04-27 23:13:47         6.62     49.12   2.92   8.08 27.42
# 7310  2022-04-27 23:43:42         6.25     49.75   3.18   8.41 18.14
#
# [7311 rows x 6 columns]

# %%
#wavertree reloved
dateswav = dfwav['Date & Time']
dateswav= pd.DatetimeIndex(dateswav)
tempwav = dfwav['Temperature']
pm2p5wav = dfwav['PM2.5']
pm10wav = dfwav['PM10']
plt.plot(dateswav,pm2p5wav, 'black')

# %%
#left widnes till last as defra
# williamson square #ok
dfwil = pd.read_csv('/home/williamson square.csv', sep=';')
dfwil
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-10 15:31:10        18.06     61.24   0.93   2.60  7.57
# 1     2021-11-10 15:36:09        18.37     65.47   0.97   2.32  6.62
# 2     2021-11-10 15:43:25        18.62     59.13   1.05   3.60  7.30
# 3     2021-11-10 15:45:08        18.90     57.88   0.93   2.65  6.15
# 4     2021-11-10 15:46:35        19.18     58.08   0.91   2.51  9.09
# ...                   ...          ...       ...    ...    ...   ...
# 7514  2022-04-27 21:34:41         8.25     81.73   2.99   7.77 16.41
# 7515  2022-04-27 22:04:29         7.88     86.79   2.93   7.39 12.74
# 7516  2022-04-27 22:34:17         7.55     91.61   3.11   9.70 22.68
# 7517  2022-04-27 23:04:05         7.26     92.69   3.67  10.47 26.97
# 7518  2022-04-27 23:33:54         6.93     96.10   3.79  10.31 30.75
#
# [7519 rows x 6 columns]

# %%
#williamson square
dateswil = dfwil['Date & Time']
dateswil= pd.DatetimeIndex(dateswil)
tempwil = dfwil['Temperature']
pm2p5wil = dfwil['PM2.5']
pm10wil = dfwil['PM10']
plt.plot(dateswil,pm2p5wil, 'black')

# %%
# winchfield road #omit
dfwin = pd.read_csv('/home/winchfield road.csv', sep=';')
dfwin
# Out:
#               Date & Time  Temperature  Humidity  PM1.0  PM2.5  PM10
# 0     2021-11-04 17:22:37        15.21     49.32   0.78   2.25  5.00
# 1     2021-11-04 17:23:53        15.53     50.64   0.71   2.22  6.15
# 2     2021-11-05 08:01:07        13.70     56.06   1.35   2.85  9.43
# 3     2021-11-05 08:31:02        13.85     53.91   1.01   4.06 30.15
# 4     2021-11-05 12:00:28        14.63     54.96   1.10   7.56 35.40
# ...                   ...          ...       ...    ...    ...   ...
# 6360  2022-04-27 21:14:49         9.04     46.01   2.26   9.25 34.41
# 6361  2022-04-27 21:44:31         7.54     48.53   2.57  10.09 26.67
# 6362  2022-04-27 22:14:28         7.08     49.34   2.96   9.44 28.51
# 6363  2022-04-27 23:14:17         6.37     50.38   3.96  10.94 32.62
# 6364  2022-04-27 23:44:13         5.97     51.02   3.91  10.85 38.64
#
# [6365 rows x 6 columns]

# %%
dfwin.drop([3280, 3281, 3282, 3283, 3284, 3285, 3286, 3287, 3288, 3289, 3290, 3291, 3292, 3293, 3294, 3295, 3296, 3297], inplace = True)

# %%
#winchfield road
dateswin = dfwin['Date & Time']
dateswin= pd.DatetimeIndex(dateswin)
tempwin = dfwin['Temperature']
pm2p5win = dfwin['PM2.5']
pm10win = dfwin['PM10']
plt.plot(dateswin,pm2p5win, 'black')

# %%
#speke defra
dfspe = pd.read_csv('/home/speke.csv', sep=';')
dfspe
# Out:
#               Date & Time  Temperature  Wind Speed  NO2  PM2.5  PM10  SO2
# 0     2021-11-01 01:00:00         9.90        6.40 1.67   1.00  7.73 1.70
# 1     2021-11-01 02:00:00         9.90        7.00 1.30   0.00  7.73 0.96
# 2     2021-11-01 03:00:00         9.60        7.20 1.02   2.00  8.70 0.83
# 3     2021-11-01 04:00:00         9.40        6.60 1.35   3.00 12.56 0.89
# 4     2021-11-01 05:00:00         9.50        6.80 1.85   3.00 10.63 1.40
# ...                   ...          ...         ...  ...    ...   ...  ...
# 3690  2022-04-03 19:00:00         4.50        2.60 6.88   6.00  6.76 2.39
# 3691  2022-04-03 20:00:00         4.40        3.00 2.87   2.00  7.73 3.99
# 3692  2022-04-03 21:00:00         5.40        3.80 0.00   0.00  6.76 2.93
# 3693  2022-04-03 22:00:00         6.40        4.70 0.00   1.00 13.53 3.19
# 3694  2022-04-03 23:00:00         7.40        5.40 0.00   4.00  8.70 3.46
#
# [3695 rows x 7 columns]

# %%
#speke defra
datesspe = dfspe['Date & Time']
datesspe= pd.DatetimeIndex(datesspe)
tempspe = dfspe['Temperature']
windspe = dfspe['Wind Speed']
no2spe = dfspe['NO2']
pm2p5spe = dfspe['PM2.5']
pm10spe = dfspe['PM10']
so2spe = dfspe['SO2']
plt.plot(datesspe,no2spe, 'black')

# %%
#brikenhead borough defra
dfbir = pd.read_csv('/home/birkenhead borough rd.csv', sep=';')
dfbir
# Out:
#               Date & Time  Temperature  Wind Speed  NO2  PM2.5  PM10  SO2
# 0     2021-11-01 01:00:00        10.10        9.30 1.45    NaN   NaN  NaN
# 1     2021-11-01 02:00:00        10.00        9.80 0.68    NaN   NaN  NaN
# 2     2021-11-01 03:00:00         9.70       10.00 0.59    NaN   NaN  NaN
# 3     2021-11-01 04:00:00         9.70        9.40 0.73    NaN   NaN  NaN
# 4     2021-11-01 05:00:00         9.70       10.10 1.30    NaN   NaN  NaN
# ...                   ...          ...         ...  ...    ...   ...  ...
# 3690  2022-04-03 19:00:00         5.10        4.20 9.75    NaN   NaN  NaN
# 3691  2022-04-03 20:00:00         5.20        5.20 4.02    NaN   NaN  NaN
# 3692  2022-04-03 21:00:00         6.40        6.00 0.96    NaN   NaN  NaN
# 3693  2022-04-03 22:00:00         6.90        6.80 0.38    NaN   NaN  NaN
# 3694  2022-04-03 23:00:00         7.70        7.80 0.38    NaN   NaN  NaN
#
# [3695 rows x 7 columns]

# %%
#brikenhead borough defra
datesbir = dfbir['Date & Time']
datesbir= pd.DatetimeIndex(datesbir)
tempbir = dfbir['Temperature']
windbir = dfbir['Wind Speed']
no2bir = dfbir['NO2']
pm2p5bir = dfbir['PM2.5']
pm10bir = dfbir['PM10']
so2bir = dfbir['SO2']
plt.plot(datesbir,no2bir, 'black')

# %%
#wirral defra
dfwir = pd.read_csv('/home/wirral tranmere.csv', sep=';')
dfwir
# Out:
#               Date & Time  Temperature  Wind Speed   NO2  PM2.5  PM10  SO2
# 0     2021-11-01 01:00:00        10.10        9.30  3.97   2.62  5.10  NaN
# 1     2021-11-01 02:00:00        10.00        9.80  3.58   3.28  7.62  NaN
# 2     2021-11-01 03:00:00         9.70       10.00  2.97   3.04  7.28  NaN
# 3     2021-11-01 04:00:00         9.70        9.40  2.88   3.58  8.55  NaN
# 4     2021-11-01 05:00:00         9.70       10.10  2.93   3.80  9.12  NaN
# ...                   ...          ...         ...   ...    ...   ...  ...
# 3690  2022-04-03 19:00:00         5.10        4.20 15.87   9.72 12.60  NaN
# 3691  2022-04-03 20:00:00         5.20        5.20  8.03   6.79  9.00  NaN
# 3692  2022-04-03 21:00:00         6.40        6.00  3.63   5.75  7.90  NaN
# 3693  2022-04-03 22:00:00         6.90        6.80  2.68   5.85  9.10  NaN
# 3694  2022-04-03 23:00:00         7.70        7.80  2.10   4.72  7.40  NaN
#
# [3695 rows x 7 columns]

# %%
#wirral defra
dateswir = dfwir['Date & Time']
dateswir= pd.DatetimeIndex(dateswir)
tempwir = dfwir['Temperature']
windwir = dfwir['Wind Speed']
no2wir = dfwir['NO2']
pm2p5wir = dfwir['PM2.5']
pm10wir = dfwir['PM10']
so2wir = dfwir['SO2']
plt.plot(dateswir,no2wir, 'black')

# %%
#widnes defra
dfwid = pd.read_csv('/home/widnes milton road.csv', sep=';')
dfwid
# Out:
#               Date & Time  Temperature  Wind Speed   NO2  PM2.5  PM10  SO2
# 0     2021-11-01 01:00:00         9.40        7.80  8.13    NaN   NaN  NaN
# 1     2021-11-01 02:00:00         9.40        9.10  1.19    NaN   NaN  NaN
# 2     2021-11-01 03:00:00         9.00        9.70  0.76    NaN   NaN  NaN
# 3     2021-11-01 04:00:00         8.90        9.10  1.50    NaN   NaN  NaN
# 4     2021-11-01 05:00:00         8.90        8.80  3.33    NaN   NaN  NaN
# ...                   ...          ...         ...   ...    ...   ...  ...
# 3690  2022-04-03 19:00:00         4.90        4.50 20.08    NaN   NaN  NaN
# 3691  2022-04-03 20:00:00         4.70        4.60 15.49    NaN   NaN  NaN
# 3692  2022-04-03 21:00:00         4.60        5.00  8.22    NaN   NaN  NaN
# 3693  2022-04-03 22:00:00         5.30        5.60  9.95    NaN   NaN  NaN
# 3694  2022-04-03 23:00:00         6.40        6.30   NaN    NaN   NaN  NaN
#
# [3695 rows x 7 columns]

# %%
#widnes defra
dateswid = dfwid['Date & Time']
dateswid= pd.DatetimeIndex(dateswid)
tempwid = dfwid['Temperature']
windwid = dfwid['Wind Speed']
no2wid = dfwid['NO2']
pm2p5wid = dfwid['PM2.5']
pm10wid = dfwid['PM10']
so2wid = dfwid['SO2']
plt.plot(dateswid,no2wid, 'black')

# %%
#st helens defra
dfsth= pd.read_csv('/home/st helens linkway.csv', sep=';')
dfsth
# Out:
#               Date & Time  Temperature  Wind Speed   NO2  PM2.5  PM10  SO2
# 0     2021-11-01 01:00:00         9.30        7.80  2.91    NaN  6.76  NaN
# 1     2021-11-01 02:00:00         9.40        8.80  1.20    NaN 11.59  NaN
# 2     2021-11-01 03:00:00         9.20        9.50  1.12    NaN 10.63  NaN
# 3     2021-11-01 04:00:00         9.10        9.60  1.69    NaN 16.43  NaN
# 4     2021-11-01 05:00:00         9.00       10.10  4.68    NaN 18.36  NaN
# ...                   ...          ...         ...   ...    ...   ...  ...
# 3690  2022-04-03 19:00:00         4.30        4.20 17.02    NaN 26.09  NaN
# 3691  2022-04-03 20:00:00         4.40        4.50 12.62    NaN 19.32  NaN
# 3692  2022-04-03 21:00:00         4.30        4.70  7.46    NaN  9.66  NaN
# 3693  2022-04-03 22:00:00         5.40        5.80  1.91    NaN  7.73  NaN
# 3694  2022-04-03 23:00:00         6.50        6.70  0.77    NaN  8.70  NaN
#
# [3695 rows x 7 columns]

# %%
#st helens defra
datessth = dfsth['Date & Time']
datessth= pd.DatetimeIndex(datessth)
tempsth = dfsth['Temperature']
windsth = dfsth['Wind Speed']
no2sth = dfsth['NO2']
pm2p5sth = dfsth['PM2.5']
pm10sth = dfsth['PM10']
so2sth = dfsth['SO2']
plt.plot(datessth,no2sth, 'black')

# %%
## this is now all the data written in and sorted
## will now attempt to average daily and plot for each one in a single piece of code

# %%
tmpaig = datesaig.day_of_year
print(datesaig.day_of_year)
# Out:
# Int64Index([305, 306, 306, 307, 307, 307, 307, 307, 307, 307,
#             ...
#             117, 117, 117, 117, 117, 117, 117, 117, 117, 117],
#            dtype='int64', name='Date & Time', length=8353)

# %%
#find daily average since installed aigburth
tmpaig = datesaig.day_of_year
dailypm2p5aig =np.zeros([177,])
c=0
for i in range(tmpaig[0], 365):
  dailypm2p5aig[c]= np.nanmean(pm2p5aig[datesaig.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm2p5aig[c]= np.nanmean(pm2p5aig[datesaig.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5aig, 'red', label='Aigburth Station PM2.5')
dailypm10aig =np.zeros([177,])
c=0
for i in range(tmpaig[0], 365):
  dailypm10aig[c]= np.nanmean(pm10aig[datesaig.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm10aig[c]= np.nanmean(pm10aig[datesaig.day_of_year==i])
  c=c+1;
plt.plot(dailypm10aig, 'blue', label='Aigburth Station PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5aig = np.nanmean(dailypm2p5aig)
print(mean_pm2p5aig)
mean_pm10aig = np.nanmean(dailypm10aig)
print(mean_pm10aig)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 35.159488778817
# 83.83621586440051

# %%
tmpall = datesaig.day_of_year
print(datesaig.day_of_year)
# Out:
# Int64Index([305, 306, 306, 307, 307, 307, 307, 307, 307, 307,
#             ...
#             117, 117, 117, 117, 117, 117, 117, 117, 117, 117],
#            dtype='int64', name='Date & Time', length=8353)

# %%
#find daily average since installed all saints
tmpall = datesall.day_of_year
dailypm2p5all =np.zeros([177,])
c=0
for i in range(tmpall[0], 365):
  dailypm2p5all[c]= np.nanmean(pm2p5all[datesall.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm2p5all[c]= np.nanmean(pm2p5all[datesall.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5all, 'red', label='All Saints Primary School PM2.5')
dailypm10all =np.zeros([177,])
c=0
for i in range(tmpall[0], 365):
  dailypm10all[c]= np.nanmean(pm10all[datesall.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm10all[c]= np.nanmean(pm10all[datesall.day_of_year==i])
  c=c+1;
plt.plot(dailypm10all, 'blue', label='All Saints Primary School PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5all = np.nanmean(dailypm2p5all)
print(mean_pm2p5all)
mean_pm10all = np.nanmean(dailypm10all)
print(mean_pm10all)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 19.773775524677053
# 87.35341396994

# %%
tmpanf = datesaig.day_of_year
print(datesaig.day_of_year)
# Out:
# Int64Index([305, 306, 306, 307, 307, 307, 307, 307, 307, 307,
#             ...
#             117, 117, 117, 117, 117, 117, 117, 117, 117, 117],
#            dtype='int64', name='Date & Time', length=8353)

# %%
#find daily average since instanfed anfield
tmpanf = datesanf.day_of_year
dailypm2p5anf =np.zeros([177,])
c=0
for i in range(tmpanf[0], 365):
  dailypm2p5anf[c]= np.nanmean(pm2p5anf[datesanf.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm2p5anf[c]= np.nanmean(pm2p5anf[datesanf.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5anf, 'red', label='Anfield PM2.5')
dailypm10anf =np.zeros([177,])
c=0
for i in range(tmpanf[0], 365):
  dailypm10anf[c]= np.nanmean(pm10anf[datesanf.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm10anf[c]= np.nanmean(pm10anf[datesanf.day_of_year==i])
  c=c+1;
plt.plot(dailypm10anf, 'blue', label='Anfield PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5anf = np.nanmean(dailypm2p5anf)
print(mean_pm2p5anf)
mean_pm10anf = np.nanmean(dailypm10anf)
print(mean_pm10anf)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 19.397753347868058
# 48.556797589057624

# %%
#find daily average since instbired birkenhead
tmpbir = datesbir.day_of_year
dailypm2p5bir =np.zeros([177,])
c=0
for i in range(tmpbir[0], 365):
  dailypm2p5bir[c]= np.nanmean(pm2p5bir[datesbir.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm2p5bir[c]= np.nanmean(pm2p5bir[datesbir.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5bir, 'red', label='birield PM2.5')
dailypm10bir =np.zeros([177,])
c=0
for i in range(tmpbir[0], 365):
  dailypm10bir[c]= np.nanmean(pm10bir[datesbir.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm10bir[c]= np.nanmean(pm10bir[datesbir.day_of_year==i])
  c=c+1;
plt.plot(dailypm10bir, 'blue', label='birield PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5bir = np.nanmean(dailypm2p5bir)
print(mean_pm2p5bir)
mean_pm10bir = np.nanmean(dailypm10bir)
print(mean_pm10bir)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: Mean of empty slice
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: RuntimeWarning: Mean of empty slice
# nan
# nan

# %%
#find daily average since instbrued briunswick
tmpbru = datesbru.day_of_year
dailypm2p5bru =np.zeros([177,])
c=0
for i in range(tmpbru[0], 365):
  dailypm2p5bru[c]= np.nanmean(pm2p5bru[datesbru.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm2p5bru[c]= np.nanmean(pm2p5bru[datesbru.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5bru, 'red', label='Brusnwick Station PM2.5')
dailypm10bru =np.zeros([177,])
c=0
for i in range(tmpbru[0], 365):
  dailypm10bru[c]= np.nanmean(pm10bru[datesbru.day_of_year==i])
  c=c+1;
for i in range(0,117):
  dailypm10bru[c]= np.nanmean(pm10bru[datesbru.day_of_year==i])
  c=c+1;
plt.plot(dailypm10bru, 'blue', label='Brusnwick Station PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5bru = np.nanmean(dailypm2p5bru)
print(mean_pm2p5bru)
mean_pm10bru = np.nanmean(dailypm10bru)
print(mean_pm10bru)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 15.082892381425832
# 40.4113157611705

# %%
#find daily average life sciences
tmplif = dateslif.day_of_year
dailypm2p5lif =np.zeros([169,])
c=0
for i in range(tmplif[0], 365):
  dailypm2p5lif[c]= np.nanmean(pm2p5lif[dateslif.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5lif[c]= np.nanmean(pm2p5lif[dateslif.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5lif, 'red', label='Life Sciences Building PM2.5')
dailypm10lif =np.zeros([169,])
c=0
for i in range(tmplif[0], 365):
  dailypm10lif[c]= np.nanmean(pm10lif[dateslif.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10lif[c]= np.nanmean(pm10lif[dateslif.day_of_year==i])
  c=c+1;
plt.plot(dailypm10lif, 'blue', label='Life Sciences Building PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5lif = np.nanmean(dailypm2p5lif)
print(mean_pm2p5lif)
mean_pm10lif = np.nanmean(dailypm10lif)
print(mean_pm10lif)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 16.908914233269822
# 53.00180284739769

# %%
#find daily average everton
tmpeve = dateseve.day_of_year
dailypm2p5eve =np.zeros([169,])
c=0
for i in range(tmpeve[0], 365):
  dailypm2p5eve[c]= np.nanmean(pm2p5eve[dateseve.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5eve[c]= np.nanmean(pm2p5eve[dateseve.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5eve, 'red', label='Everton Valley PM2.5')
dailypm10eve =np.zeros([169,])
c=0
for i in range(tmpeve[0], 365):
  dailypm10eve[c]= np.nanmean(pm10eve[dateseve.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10eve[c]= np.nanmean(pm10eve[dateseve.day_of_year==i])
  c=c+1;
plt.plot(dailypm10eve, 'blue', label='Everton Valley PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5eve = np.nanmean(dailypm2p5eve)
print(mean_pm2p5eve)
mean_pm10eve = np.nanmean(dailypm10eve)
print(mean_pm10eve)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 28.160277476144362
# 76.16898281199126

# %%
#find daily average Garston
tmpgar = datesgar.day_of_year
dailypm2p5gar =np.zeros([169,])
c=0
for i in range(tmpgar[0], 365):
  dailypm2p5gar[c]= np.nanmean(pm2p5gar[datesgar.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5gar[c]= np.nanmean(pm2p5gar[datesgar.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5gar, 'red', label='Garston PM2.5')
dailypm10gar =np.zeros([169,])
c=0
for i in range(tmpgar[0], 365):
  dailypm10gar[c]= np.nanmean(pm10gar[datesgar.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10gar[c]= np.nanmean(pm10gar[datesgar.day_of_year==i])
  c=c+1;
plt.plot(dailypm10gar, 'blue', label='Garston PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5gar = np.nanmean(dailypm2p5gar)
print(mean_pm2p5gar)
mean_pm10gar = np.nanmean(dailypm10gar)
print(mean_pm10gar)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 12.611434240749722
# 38.29069511674659

# %%
#find daily average Kirkdale
tmpkir = dateskir.day_of_year
dailypm2p5kir =np.zeros([169,])
c=0
for i in range(tmpkir[0], 365):
  dailypm2p5kir[c]= np.nanmean(pm2p5kir[dateskir.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5kir[c]= np.nanmean(pm2p5kir[dateskir.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5kir, 'red', label='Kirkdale Station PM2.5')
dailypm10kir =np.zeros([169,])
c=0
for i in range(tmpkir[0], 365):
  dailypm10kir[c]= np.nanmean(pm10kir[dateskir.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10kir[c]= np.nanmean(pm10kir[dateskir.day_of_year==i])
  c=c+1;
plt.plot(dailypm10kir, 'blue', label='Kirkdale Station PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5kir = np.nanmean(dailypm2p5kir)
print(mean_pm2p5kir)
mean_pm10kir = np.nanmean(dailypm10kir)
print(mean_pm10kir)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 17.63997763730801
# 46.253404357871936

# %%
#find daily average life sceinces
tmplif = dateslif.day_of_year
dailypm2p5lif =np.zeros([169,])
c=0
for i in range(tmplif[0], 365):
  dailypm2p5lif[c]= np.nanmean(pm2p5lif[dateslif.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5lif[c]= np.nanmean(pm2p5lif[dateslif.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5lif, 'red', label='Life Sciences Building PM2.5')
dailypm10lif =np.zeros([169,])
c=0
for i in range(tmplif[0], 365):
  dailypm10lif[c]= np.nanmean(pm10lif[dateslif.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10lif[c]= np.nanmean(pm10lif[dateslif.day_of_year==i])
  c=c+1;
plt.plot(dailypm10lif, 'blue', label='Life Sciences Building PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5lif = np.nanmean(dailypm2p5lif)
print(mean_pm2p5lif)
mean_pm10lif = np.nanmean(dailypm10lif)
print(mean_pm10lif)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 16.908914233269822
# 53.00180284739769

# %%
tmplpc = dateslpc.day_of_year
print(tmplpc)
# Out:
# Int64Index([305, 305, 305, 305, 305, 305, 305, 305, 305, 305,
#             ...
#             117, 117, 117, 117, 117, 117, 117, 117, 117, 117],
#            dtype='int64', name='Date & Time', length=5427)

# %%
#find daily average liverpool central
tmplpc = dateslpc.day_of_year
dailypm2p5lpc =np.zeros([169,])
c=0
for i in range(tmplpc[0], 365):
  dailypm2p5lpc[c]= np.nanmean(pm2p5lpc[dateslpc.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5lpc[c]= np.nanmean(pm2p5lpc[dateslpc.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5lpc, 'red', label='Liverpool Central Station PM2.5')
dailypm10lpc =np.zeros([169,])
c=0
for i in range(tmplpc[0], 365):
  dailypm10lpc[c]= np.nanmean(pm10lpc[dateslpc.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10lpc[c]= np.nanmean(pm10lpc[dateslpc.day_of_year==i])
  c=c+1;
plt.plot(dailypm10lpc, 'blue', label='Liverpool Central Station PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5lpc = np.nanmean(dailypm2p5lpc)
print(mean_pm2p5lpc)
mean_pm10lpc = np.nanmean(dailypm10lpc)
print(mean_pm10lpc)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 69.93856728429782
# 96.87029084009536

# %%
tmpjmu = datesjmu.day_of_year
print(datesjmu.day_of_year)
# Out:
# Int64Index([306, 306, 306, 306, 307, 307, 307, 307, 307, 307,
#             ...
#             117, 117, 117, 117, 117, 117, 117, 117, 117, 117],
#            dtype='int64', name='Date & Time', length=8799)

# %%
#find daily average ljmu
tmpjmu = datesjmu.day_of_year
dailypm2p5jmu =np.zeros([169,])
c=0
for i in range(tmpjmu[0], 365):
  dailypm2p5jmu[c]= np.nanmean(pm2p5jmu[datesjmu.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5jmu[c]= np.nanmean(pm2p5jmu[datesjmu.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5jmu, 'red', label='LJMU Henry Cotton PM2.5')
dailypm10jmu =np.zeros([169,])
c=0
for i in range(tmpjmu[0], 365):
  dailypm10jmu[c]= np.nanmean(pm10jmu[datesjmu.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10jmu[c]= np.nanmean(pm10jmu[datesjmu.day_of_year==i])
  c=c+1;
plt.plot(dailypm10jmu, 'blue', label='LJMU Henry Cotton PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5jmu = np.nanmean(dailypm2p5jmu)
print(mean_pm2p5jmu)
mean_pm10jmu = np.nanmean(dailypm10jmu)
print(mean_pm10jmu)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 13.240978593054573
# 34.2271909276441

# %%
#find daily average old haymarket
tmphay = dateshay.day_of_year
dailypm2p5hay =np.zeros([169,])
c=0
for i in range(tmphay[0], 365):
  dailypm2p5hay[c]= np.nanmean(pm2p5hay[dateshay.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5hay[c]= np.nanmean(pm2p5hay[dateshay.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5hay, 'red', label='Old Haymarket  PM2.5')
dailypm10hay =np.zeros([169,])
c=0
for i in range(tmphay[0], 365):
  dailypm10hay[c]= np.nanmean(pm10hay[dateshay.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10hay[c]= np.nanmean(pm10hay[dateshay.day_of_year==i])
  c=c+1;
plt.plot(dailypm10hay, 'blue', label='Old Haymarket PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5hay = np.nanmean(dailypm2p5hay)
print(mean_pm2p5hay)
mean_pm10hay = np.nanmean(dailypm10hay)
print(mean_pm10hay)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 18.454041800432865
# 46.02649355149002

# %%
#find daily average old swan
tmposw = datesosw.day_of_year
dailypm2p5osw =np.zeros([169,])
c=0
for i in range(tmposw[0], 365):
  dailypm2p5osw[c]= np.nanmean(pm2p5osw[datesosw.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5osw[c]= np.nanmean(pm2p5osw[datesosw.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5osw, 'red', label='Old Swan PM10 PM2.5')
dailypm10osw =np.zeros([169,])
c=0
for i in range(tmposw[0], 365):
  dailypm10osw[c]= np.nanmean(pm10osw[datesosw.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10osw[c]= np.nanmean(pm10osw[datesosw.day_of_year==i])
  c=c+1;
plt.plot(dailypm10osw, 'blue', label='Old Swan PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5osw = np.nanmean(dailypm2p5osw)
print(mean_pm2p5osw)
mean_pm10osw = np.nanmean(dailypm10osw)
print(mean_pm10osw)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 32.88550111776078
# 104.74630221102473

# %%
#find daily average Queens square
tmpqsq = datesqsq.day_of_year
dailypm2p5qsq =np.zeros([169,])
c=0
for i in range(tmpqsq[0], 365):
  dailypm2p5qsq[c]= np.nanmean(pm2p5qsq[datesqsq.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5qsq[c]= np.nanmean(pm2p5qsq[datesqsq.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5qsq, 'red', label='Queens Square PM2.5')
dailypm10qsq =np.zeros([169,])
c=0
for i in range(tmpqsq[0], 365):
  dailypm10qsq[c]= np.nanmean(pm10qsq[datesqsq.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10qsq[c]= np.nanmean(pm10qsq[datesqsq.day_of_year==i])
  c=c+1;
plt.plot(dailypm10qsq, 'blue', label='Queens Square PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5qsq = np.nanmean(dailypm2p5qsq)
print(mean_pm2p5qsq)
mean_pm10qsq = np.nanmean(dailypm10qsq)
print(mean_pm10qsq)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 90.63449763629193
# 103.30881468352024

# %%
tmpreg = datesreg.day_of_year
print(datesreg.day_of_year)
# Out:
# Int64Index([ 38,  38,  38,  38,  38,  39,  39,  39,  39,  39,
#             ...
#             117, 117, 117, 117, 117, 117, 117, 117, 117, 117],
#            dtype='int64', name='Date & Time', length=4865)

# %%
#find daily average roxby
tmprox = datesrox.day_of_year
dailypm2p5rox =np.zeros([169,])
c=0
for i in range(tmprox[0], 365):
  dailypm2p5rox[c]= np.nanmean(pm2p5rox[datesrox.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5rox[c]= np.nanmean(pm2p5rox[datesrox.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5rox, 'red', label='Roxby Building PM2.5')
dailypm10rox =np.zeros([169,])
c=0
for i in range(tmprox[0], 365):
  dailypm10rox[c]= np.nanmean(pm10rox[datesrox.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10rox[c]= np.nanmean(pm10rox[datesrox.day_of_year==i])
  c=c+1;
plt.plot(dailypm10rox, 'blue', label='Roxby Building PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5rox = np.nanmean(dailypm2p5rox)
print(mean_pm2p5rox)
mean_pm10rox = np.nanmean(dailypm10rox)
print(mean_pm10rox)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 20.235423015223848
# 76.07253110842323

# %%
#find daily average st nicolas
tmpnic = datesnic.day_of_year
dailypm2p5nic =np.zeros([169,])
c=0
for i in range(tmpnic[0], 365):
  dailypm2p5nic[c]= np.nanmean(pm2p5nic[datesnic.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5nic[c]= np.nanmean(pm2p5nic[datesnic.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5nic, 'red', label='St Nicolas PM2.5')
dailypm10nic =np.zeros([169,])
c=0
for i in range(tmpnic[0], 365):
  dailypm10nic[c]= np.nanmean(pm10nic[datesnic.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10nic[c]= np.nanmean(pm10nic[datesnic.day_of_year==i])
  c=c+1;
plt.plot(dailypm10nic, 'blue', label='St Nicolas PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5nic = np.nanmean(dailypm2p5nic)
print(mean_pm2p5nic)
mean_pm10nic = np.nanmean(dailypm10nic)
print(mean_pm10nic)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 14.00757590617764
# 47.371266526444046

# %%
#find daily average strand albert dock
tmpsad = datessad.day_of_year
dailypm2p5sad =np.zeros([169,])
c=0
for i in range(tmpsad[0], 365):
  dailypm2p5sad[c]= np.nanmean(pm2p5sad[datessad.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5sad[c]= np.nanmean(pm2p5sad[datessad.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5sad, 'red', label='Strand Albert Dock PM2.5')
dailypm10sad =np.zeros([169,])
c=0
for i in range(tmpsad[0], 365):
  dailypm10sad[c]= np.nanmean(pm10sad[datessad.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10sad[c]= np.nanmean(pm10sad[datessad.day_of_year==i])
  c=c+1;
plt.plot(dailypm10sad, 'blue', label='Strand Albert Dock PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5sad = np.nanmean(dailypm2p5sad)
print(mean_pm2p5sad)
mean_pm10sad = np.nanmean(dailypm10sad)
print(mean_pm10sad)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 80.17078354751847
# 150.09408974037902

# %%
#find daily average strand chavasse
tmpscp = datesscp.day_of_year
dailypm2p5scp =np.zeros([169,])
c=0
for i in range(tmpscp[0], 365):
  dailypm2p5scp[c]= np.nanmean(pm2p5scp[datesscp.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5scp[c]= np.nanmean(pm2p5scp[datesscp.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5scp, 'red', label='Strand Chavasse Park PM2.5')
dailypm10scp =np.zeros([169,])
c=0
for i in range(tmpscp[0], 365):
  dailypm10scp[c]= np.nanmean(pm10scp[datesscp.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10scp[c]= np.nanmean(pm10scp[datesscp.day_of_year==i])
  c=c+1;
plt.plot(dailypm10scp, 'blue', label='Strand Chavasse Park PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5scp = np.nanmean(dailypm2p5scp)
print(mean_pm2p5scp)
mean_pm10scp = np.nanmean(dailypm10scp)
print(mean_pm10scp)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 72.59692658846102
# 132.61603667199893

# %%
#find daily average uol maths
tmpuol = datesuol.day_of_year
dailypm2p5uol =np.zeros([169,])
c=0
for i in range(tmpuol[0], 365):
  dailypm2p5uol[c]= np.nanmean(pm2p5uol[datesuol.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5uol[c]= np.nanmean(pm2p5uol[datesuol.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5uol, 'red', label='UOL Maths Building PM2.5')
dailypm10uol =np.zeros([169,])
c=0
for i in range(tmpuol[0], 365):
  dailypm10uol[c]= np.nanmean(pm10uol[datesuol.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10uol[c]= np.nanmean(pm10uol[datesuol.day_of_year==i])
  c=c+1;
plt.plot(dailypm10uol, 'blue', label='UOL Maths Building PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5uol = np.nanmean(dailypm2p5uol)
print(mean_pm2p5uol)
mean_pm10uol = np.nanmean(dailypm10uol)
print(mean_pm10uol)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 23.97204308084652
# 55.767631818900746

# %%
#find daily average wavertree
tmpwav = dateswav.day_of_year
dailypm2p5wav =np.zeros([169,])
c=0
for i in range(tmpwav[0], 365):
  dailypm2p5wav[c]= np.nanmean(pm2p5wav[dateswav.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5wav[c]= np.nanmean(pm2p5wav[dateswav.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5wav, 'red', label='Wavertree PM2.5')
dailypm10wav =np.zeros([169,])
c=0
for i in range(tmpwav[0], 365):
  dailypm10wav[c]= np.nanmean(pm10wav[dateswav.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10wav[c]= np.nanmean(pm10wav[dateswav.day_of_year==i])
  c=c+1;
plt.plot(dailypm10wav, 'blue', label='Wavertree PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5wav = np.nanmean(dailypm2p5wav)
print(mean_pm2p5wav)
mean_pm10wav = np.nanmean(dailypm10wav)
print(mean_pm10wav)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 14.29566596769717
# 55.019268825470064

# %%
#find daily average williamson square
tmpwil = dateswil.day_of_year
dailypm2p5wil =np.zeros([169,])
c=0
for i in range(tmpwil[0], 365):
  dailypm2p5wil[c]= np.nanmean(pm2p5wil[dateswil.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5wil[c]= np.nanmean(pm2p5wil[dateswil.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5wil, 'red', label='Williamson Square PM2.5')
dailypm10wil =np.zeros([169,])
c=0
for i in range(tmpwil[0], 365):
  dailypm10wil[c]= np.nanmean(pm10wil[dateswil.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10wil[c]= np.nanmean(pm10wil[dateswil.day_of_year==i])
  c=c+1;
plt.plot(dailypm10wil, 'blue', label='Williamson Square PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5wil = np.nanmean(dailypm2p5wil)
print(mean_pm2p5wil)
mean_pm10wil = np.nanmean(dailypm10wil)
print(mean_pm10wil)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 15.476966210608133
# 30.20138799809881

# %%
#find daily average winchfield road
tmpwin = dateswin.day_of_year
dailypm2p5win =np.zeros([169,])
c=0
for i in range(tmpwin[0], 365):
  dailypm2p5win[c]= np.nanmean(pm2p5win[dateswin.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5win[c]= np.nanmean(pm2p5win[dateswin.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5win, 'red', label='Winchfield Road PM2.5')
dailypm10win =np.zeros([169,])
c=0
for i in range(tmpwin[0], 365):
  dailypm10win[c]= np.nanmean(pm10win[dateswin.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10win[c]= np.nanmean(pm10win[dateswin.day_of_year==i])
  c=c+1;
plt.plot(dailypm10win, 'blue', label='Winchfield Road PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5win = np.nanmean(dailypm2p5win)
print(mean_pm2p5win)
mean_pm10win = np.nanmean(dailypm10win)
print(mean_pm10win)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# 13.53785434708416
# 52.764858205200305

# %%
#try defra now
#birkenhead only NO2
tmpbir = datesbir.day_of_year
dailyno2bir =np.zeros([169,])
c=0
for i in range(tmpbir[0], 365):
  dailyno2bir[c]= np.nanmean(no2bir[datesbir.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailyno2bir[c]= np.nanmean(no2bir[datesbir.day_of_year==i])
  c=c+1;
plt.plot(dailyno2bir, 'blue', label='Birkenhead NO2')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_so2bir = np.nanmean(dailyso2bir)
print(mean_so2bir)
mean_no2bir = np.nanmean(dailyno2bir)
print(mean_no2bir)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: Mean of empty slice
#   app.launch_new_instance()
# nan
# 21.05635610007535

# %%
#try defra now
#speke pms
tmpspe = datesspe.day_of_year
dailypm2p5spe =np.zeros([169,])
c=0
for i in range(tmpspe[0], 365):
  dailypm2p5spe[c]= np.nanmean(pm2p5spe[datesspe.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5spe[c]= np.nanmean(pm2p5spe[datesspe.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5spe, 'red', label='Speke PM2.5')
dailypm10spe =np.zeros([169,])
c=0
for i in range(tmpspe[0], 365):
  dailypm10spe[c]= np.nanmean(pm10spe[datesspe.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10spe[c]= np.nanmean(pm10spe[datesspe.day_of_year==i])
  c=c+1;
plt.plot(dailypm10spe, 'blue', label='Speke PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5spe = np.nanmean(dailypm2p5spe)
print(mean_pm2p5spe)
mean_pm10spe = np.nanmean(dailypm10spe)
print(mean_pm10spe)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: Mean of empty slice
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: Mean of empty slice
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: Mean of empty slice
# 7.5891712733500185
# 16.824211831141167

# %%
#try defra now
#speke no2 and so2
tmpspe = datesspe.day_of_year
dailyno2spe =np.zeros([169,])
c=0
for i in range(tmpspe[0], 365):
  dailyno2spe[c]= np.nanmean(no2spe[datesspe.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailyno2spe[c]= np.nanmean(no2spe[datesspe.day_of_year==i])
  c=c+1;
plt.plot(dailyno2spe, 'red', label='Speke NO2')
dailyso2spe =np.zeros([169,])
c=0
for i in range(tmpspe[0], 365):
  dailyso2spe[c]= np.nanmean(so2spe[datesspe.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailyso2spe[c]= np.nanmean(so2spe[datesspe.day_of_year==i])
  c=c+1;
plt.plot(dailyso2spe, 'blue', label='Speke SO2')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_no2spe = np.nanmean(dailyno2spe)
print(mean_no2spe)
mean_so2spe = np.nanmean(dailyso2spe)
print(mean_so2spe)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: Mean of empty slice
# 17.83076682016856
# 3.435579164750661

# %%
#try defra now
#st helens pms
tmpsth = datessth.day_of_year
dailypm2p5sth =np.zeros([169,])
c=0
for i in range(tmpsth[0], 365):
  dailypm2p5sth[c]= np.nanmean(pm2p5sth[datessth.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5sth[c]= np.nanmean(pm2p5sth[datessth.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5sth, 'red', label='St Helens Linkway PM2.5')
dailypm10sth =np.zeros([169,])
c=0
for i in range(tmpsth[0], 365):
  dailypm10sth[c]= np.nanmean(pm10sth[datessth.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10sth[c]= np.nanmean(pm10sth[datessth.day_of_year==i])
  c=c+1;
plt.plot(dailypm10sth, 'blue', label='St Helens Linkway PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5sth = np.nanmean(dailypm2p5sth)
print(mean_pm2p5sth)
mean_pm10sth = np.nanmean(dailypm10sth)
print(mean_pm10sth)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: Mean of empty slice
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: Mean of empty slice
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: Mean of empty slice
# nan
# 21.75201791062802

# %%
#try defra now
#st helns so2 no2
tmpsth = datessth.day_of_year
dailyno2sth =np.zeros([169,])
c=0
for i in range(tmpsth[0], 365):
  dailyno2sth[c]= np.nanmean(no2sth[datessth.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailyno2sth[c]= np.nanmean(no2sth[datessth.day_of_year==i])
  c=c+1;
plt.plot(dailyno2sth, 'red', label='St Helens Linkway NO2')
dailyso2sth =np.zeros([169,])
c=0
for i in range(tmpsth[0], 365):
  dailyso2sth[c]= np.nanmean(so2sth[datessth.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailyso2sth[c]= np.nanmean(so2sth[datessth.day_of_year==i])
  c=c+1;
plt.plot(dailyso2sth, 'blue', label='St Helens Linkway SO2')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_no2sth = np.nanmean(dailyno2sth)
print(mean_no2sth)
mean_so2sth = np.nanmean(dailyso2sth)
print(mean_so2sth)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: Mean of empty slice
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: Mean of empty slice
# 31.986919607826227
# nan
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: Mean of empty slice

# %%
#try defra now
#widnes no2
tmpwid = dateswid.day_of_year
dailyno2wid =np.zeros([169,])
c=0
for i in range(tmpwid[0], 365):
  dailyno2wid[c]= np.nanmean(no2wid[dateswid.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailyno2wid[c]= np.nanmean(no2wid[dateswid.day_of_year==i])
  c=c+1;
plt.plot(dailyno2wid, 'red', label='Widnes NO2')
dailyso2wid =np.zeros([169,])
c=0
for i in range(tmpwid[0], 365):
  dailyso2wid[c]= np.nanmean(so2wid[dateswid.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailyso2wid[c]= np.nanmean(so2wid[dateswid.day_of_year==i])
  c=c+1;
plt.plot(dailyso2wid, 'blue', label='Widnes SO2')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_no2wid = np.nanmean(dailyno2wid)
print(mean_no2wid)
mean_so2wid = np.nanmean(dailyso2wid)
print(mean_so2wid)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: Mean of empty slice
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: Mean of empty slice
# 31.94043913677813
# nan
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: Mean of empty slice

# %%
#try defra now
#wirral pms
tmpwir = dateswir.day_of_year
dailypm2p5wir =np.zeros([169,])
c=0
for i in range(tmpwir[0], 365):
  dailypm2p5wir[c]= np.nanmean(pm2p5wir[dateswir.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm2p5wir[c]= np.nanmean(pm2p5wir[dateswir.day_of_year==i])
  c=c+1;
plt.plot(dailypm2p5wir, 'red', label='Wirral Tranmere PM2.5')
dailypm10wir =np.zeros([169,])
c=0
for i in range(tmpwir[0], 365):
  dailypm10wir[c]= np.nanmean(pm10wir[dateswir.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailypm10wir[c]= np.nanmean(pm10wir[dateswir.day_of_year==i])
  c=c+1;
plt.plot(dailypm10wir, 'blue', label='Wirral Tranmere PM10')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_pm2p5wir = np.nanmean(dailypm2p5wir)
print(mean_pm2p5wir)
mean_pm10wir = np.nanmean(dailypm10wir)
print(mean_pm10wir)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: Mean of empty slice
# 9.379327027819675
# 14.686753002018348

# %%
#try defra now
#wirral tranmere no2 so2
tmpwir = dateswir.day_of_year
dailyno2wir =np.zeros([169,])
c=0
for i in range(tmpwir[0], 365):
  dailyno2wir[c]= np.nanmean(no2wir[dateswir.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailyno2wir[c]= np.nanmean(no2wir[dateswir.day_of_year==i])
  c=c+1;
plt.plot(dailyno2wir, 'red', label='Wirral Tranmere NO2')
dailyso2wir =np.zeros([169,])
c=0
for i in range(tmpwir[0], 365):
  dailyso2wir[c]= np.nanmean(so2wir[dateswir.day_of_year==i])
  c=c+1;
for i in range(0,109):
  dailyso2wir[c]= np.nanmean(so2wir[dateswir.day_of_year==i])
  c=c+1;
plt.plot(dailyso2wir, 'blue', label='Wirral Tranmere SO2')
plt.legend()
plt.ylabel('Daily average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Days since sensor was turned on') # add some lables
mean_no2wir = np.nanmean(dailyno2wir)
print(mean_no2wir)
mean_so2wir = np.nanmean(dailyso2wir)
print(mean_so2wir)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: Mean of empty slice
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: Mean of empty slice
# 15.56424195965858
# nan
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: Mean of empty slice

# %%
##histograms for all now

# %%
#histogram for three sites pm10
fig, ax = plt.subplots(figsize=(9,5))
plt.hist([pm10wr, pm10gn, pm10ev], bins=100,range=[0,100], color= ('blue', 'black', 'red'), histtype='step', linewidth=2,
        alpha=0.7, label=['Winchfield Road PM10', 
                          'Garston PM10', 
                          'Everton Valley PM10'])
plt.ylabel('Frequency')
plt.xlabel('Range')
plt.legend()

# %%
#histogram for all sites pm2.5
plt.figure(figsize=(8,8)) #change your figure size as per your desire here
n,bins,patch = plt.hist([dailypm2p5aig, dailypm2p5all, dailypm2p5anf, dailypm2p5bir, dailypm2p5bru, dailypm2p5eve, dailypm2p5gar, dailypm2p5kir, dailypm2p5lif, dailypm2p5lpc, dailypm2p5jmu, dailypm2p5hay, dailypm2p5osw, dailypm2p5qsq, dailypm2p5rox,
                         dailypm2p5spe, dailypm2p5sth, dailypm2p5nic, dailypm2p5sad, dailypm2p5scp, dailypm2p5uol, dailypm2p5wav, dailypm2p5wid, dailypm2p5wil, dailypm2p5win, dailypm2p5wir], bins=75, range=[0,200], color=('black', 'grey', 'rosybrown', 'lightcoral', 
                                                                                                                                                                                                                'brown', 'red', 'orangered', 'sienna', 'peachpuff',
                                                                                                                                                                                                                'burlywood', 'orange', 'gold', 'khaki', 'olive', 
                                                                                                                                                                                                                'yellow', 'lawngreen', 'lime', 'aquamarine', 'turquoise',
                                                                                                                                                                                                                'aqua', 'deepskyblue', 'royalblue', 'slateblue', 'blueviolet',
                                                                                                                                                                                                                'fuchsia', 'pink'), histtype='step', linewidth=2,
                           alpha=0.7, label=['Aigburth Station PM2.5','All Saints Primary PM2.5', 'Anfield' ,'Birkenhead PM2.5','Brunswick PM2.5','Everton Valley PM2.5','Garston PM2.5','Kirkdale Station PM2.5','Life Sciences Building PM2.5',
                        'Liverpool Central Station PM2.5','LJMU PM2.5','Old Haymarket PM2.5','Old Swan PM2.5','Queens Square PM2.5','Roxby Building PM2.5', 'Speke PM2.5', 'St Helens Linkway PM2.5',
                        'St Nicolas PM2.5', 'Strand Albert Dock PM2.5', 'Strand Chavasse Park PM2.5', 'UOL Maths Building PM2.5', 'Wavertree PM2.5', 'Widnes Milton Road PM2.5','Williamson Square', 'Winchfield Road', 'Wirral Tranmere PM2.5'])
plt.ylabel('Frequency')
plt.xlabel('Range')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#histogram for all sites pm10
plt.figure(figsize=(8,8)) #change your figure size as per your desire here
n,bins,patch = plt.hist([dailypm10aig, dailypm10all, dailypm10anf, dailypm10bir, dailypm10bru, dailypm10eve, dailypm10gar, dailypm10kir, dailypm10lif, dailypm10lpc, dailypm10jmu, dailypm10hay, dailypm10osw, dailypm10qsq, dailypm10rox,
                         dailypm10spe, dailypm10sth, dailypm10nic, dailypm10sad, dailypm10scp, dailypm10uol, dailypm10wav, dailypm10wid, dailypm10wil, dailypm10win, dailypm10wir], bins=75, range=[0,200], color=('black', 'grey', 'rosybrown', 'lightcoral', 
                                                                                                                                                                                                                'brown', 'red', 'orangered', 'sienna', 'peachpuff',
                                                                                                                                                                                                                'burlywood', 'orange', 'gold', 'khaki', 'olive', 
                                                                                                                                                                                                                'yellow', 'lawngreen', 'lime', 'aquamarine', 'turquoise',
                                                                                                                                                                                                                'aqua', 'deepskyblue', 'royalblue', 'slateblue', 'blueviolet',
                                                                                                                                                                                                                'fuchsia', 'pink'), histtype='step', linewidth=2,
                           alpha=0.7, label=['Aigburth Station PM10','All Saints Primary PM10','Birkenhead PM10','Brunswick PM10','Everton Valley PM10','Garston PM10','Kirkdale PM10','Life Sciences Building PM10',
                        'Liverool Central Station PM10','LJMU PM10','Old Haymarket PM10','Old Swan PM10','Queens Square PM10','Roxby Building PM10', 'Speke PM10', 'St Helens Linkway PM10',
                        'St Nicolas PM10', 'Strand Albert Dock PM10', 'Strand Chavasse Park PM10', 'UOL Maths Building PM10', 'Wavertree PM10', 'Widnes Milton Road PM10', 'Wirral Tranmere PM10'])
plt.ylabel('Frequency')
plt.xlabel('Range')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#calculate pollutants throughout the day for pm2.5 aigburth
ave_pm2p5aig_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5aig_hours[i] = np.nanmean(pm2p5aig[datesaig.hour == i])
plt.plot(ave_pm2p5aig_hours,'blue', label='Aigburth 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 all saints
ave_pm2p5all_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5all_hours[i] = np.nanmean(pm2p5all[datesall.hour == i])
plt.plot(ave_pm2p5all_hours,'blue', label='All Saints 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 Anfield
ave_pm2p5anf_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5anf_hours[i] = np.nanmean(pm2p5anf[datesanf.hour == i])
plt.plot(ave_pm2p5anf_hours,'blue', label='Anfield 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#brukenhead doesnt have
#calculate pollutants throughout the day for pm2.5 Brunswick
ave_pm2p5bru_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5bru_hours[i] = np.nanmean(pm2p5bru[datesbru.hour == i])
plt.plot(ave_pm2p5bru_hours,'blue', label='Brunswick station 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 Everton Valley
ave_pm2p5eve_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5eve_hours[i] = np.nanmean(pm2p5eve[dateseve.hour == i])
plt.plot(ave_pm2p5eve_hours,'blue', label='Everton Valley 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 Garston
ave_pm2p5gar_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5gar_hours[i] = np.nanmean(pm2p5gar[datesgar.hour == i])
plt.plot(ave_pm2p5gar_hours,'blue', label='Garston 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 Kirkdale Station
ave_pm2p5kir_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5kir_hours[i] = np.nanmean(pm2p5kir[dateskir.hour == i])
plt.plot(ave_pm2p5kir_hours,'blue', label='Kirkdale Station 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 Life Sciences Building
ave_pm2p5lif_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5lif_hours[i] = np.nanmean(pm2p5lif[dateslif.hour == i])
plt.plot(ave_pm2p5lif_hours,'blue', label='Life Sciences Building 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 Liverpool Central station
ave_pm2p5lpc_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5lpc_hours[i] = np.nanmean(pm2p5lpc[dateslpc.hour == i])
plt.plot(ave_pm2p5lpc_hours,'blue', label='Liverpool Central Station 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 LJMU Henry Cotton
ave_pm2p5jmu_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5jmu_hours[i] = np.nanmean(pm2p5jmu[datesjmu.hour == i])
plt.plot(ave_pm2p5jmu_hours,'blue', label='LJMU Henry Cotton 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
## dont need labels now just read and copy off histogram code!!!

# %%
#calculate pollutants throughout the day for pm2.5 hay
ave_pm2p5hay_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5hay_hours[i] = np.nanmean(pm2p5hay[dateshay.hour == i])
plt.plot(ave_pm2p5hay_hours,'blue')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 swan
ave_pm2p5osw_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5osw_hours[i] = np.nanmean(pm2p5osw[datesosw.hour == i])
plt.plot(ave_pm2p5osw_hours,'blue')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 queens
ave_pm2p5qsq_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5qsq_hours[i] = np.nanmean(pm2p5qsq[datesqsq.hour == i])
plt.plot(ave_pm2p5qsq_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 roxby
ave_pm2p5rox_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5rox_hours[i] = np.nanmean(pm2p5rox[datesrox.hour == i])
plt.plot(ave_pm2p5rox_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 speke
ave_pm2p5spe_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5spe_hours[i] = np.nanmean(pm2p5spe[datesspe.hour == i])
plt.plot(ave_pm2p5spe_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#st helens no pm2.5
#calculate pollutants throughout the day for pm2.5 st nicolas
ave_pm2p5nic_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5nic_hours[i] = np.nanmean(pm2p5nic[datesnic.hour == i])
plt.plot(ave_pm2p5nic_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 sttand ablbert
ave_pm2p5sad_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5sad_hours[i] = np.nanmean(pm2p5sad[datessad.hour == i])
plt.plot(ave_pm2p5sad_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 stand chavasse
ave_pm2p5scp_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5scp_hours[i] = np.nanmean(pm2p5scp[datesscp.hour == i])
plt.plot(ave_pm2p5scp_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 uol
ave_pm2p5uol_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5uol_hours[i] = np.nanmean(pm2p5uol[datesuol.hour == i])
plt.plot(ave_pm2p5uol_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 wavertree
ave_pm2p5wav_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5wav_hours[i] = np.nanmean(pm2p5wav[dateswav.hour == i])
plt.plot(ave_pm2p5wav_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 wdiens
ave_pm2p5wid_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5wid_hours[i] = np.nanmean(pm2p5wid[dateswid.hour == i])
plt.plot(ave_pm2p5wid_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice
#   after removing the cwd from sys.path.
# Text(0.5, 0, 'Hours')

# %%
# widnes no pm2.5
#calculate pollutants throughout the day for pm2.5 williamspon
ave_pm2p5wil_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5wil_hours[i] = np.nanmean(pm2p5wil[dateswil.hour == i])
plt.plot(ave_pm2p5wil_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 winchfiedl 
ave_pm2p5win_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5win_hours[i] = np.nanmean(pm2p5win[dateswin.hour == i])
plt.plot(ave_pm2p5win_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm2.5 wirral
ave_pm2p5wir_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm2p5wir_hours[i] = np.nanmean(pm2p5wir[dateswir.hour == i])
plt.plot(ave_pm2p5wir_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#line graph for all sites hourly pm2.5
#plt.figure((figsize=(8, 6), dpi=80,
plt.plot([ave_pm2p5aig_hours, ave_pm2p5all_hours, ave_pm2p5anf_hours, ave_pm2p5bir_hours, ave_pm2p5bru_hours, ave_pm2p5eve_hours, ave_pm2p5gar_hours, ave_pm2p5kir_hours, ave_pm2p5lif_hours, ave_pm2p5lpc_hours, ave_pm2p5jmu_hours, 
                ave_pm2p5hay_hours, ave_pm2p5osw_hours, ave_pm2p5qsq_hours, ave_pm2p5rox_hours, ave_pm2p5spe_hours, ave_pm2p5sth_hours, ave_pm2p5nic_hours, ave_pm2p5sad_hours, ave_pm2p5scp_hours, ave_pm2p5uol_hours, 
                ave_pm2p5wav_hours, ave_pm2p5wid_hours, ave_pm2p5wil_hours, ave_pm2p5win_hours, ave_pm2p5wir_hours]) 
          color=('black', 'grey', 'rosybrown', 'lightcoral', 'brown', 'red', 'orangered', 'sienna', 'peachpuff',
                'burlywood', 'orange', 'gold', 'khaki', 'olive', 'yellow', 'lawngreen', 'lime', 'aquamarine', 'turquoise', 'aqua', 'deepskyblue', 'royalblue', 'slateblue', 'blueviolet', 'fuchsia', 'pink'),
                    label=['Aigburth Station PM2.5','All Saints Primary PM2.5','Birkenhead PM2.5','Brunswick PM2.5','Everton Valley PM2.5','Garston PM2.5','Kirkdale PM2.5','Life Sciences Building PM2.5',
                        'Liverool Central Station PM2.5','LJMU PM2.5','Old Haymarket PM2.5','Old Swan PM2.5','Queens Square PM2.5','Roxby Building PM2.5', 'Speke PM2.5', 'St Helens Linkway PM2.5',
                        'St Nicolas PM2.5', 'Strand Albert Dock PM2.5', 'Strand Chavasse Park PM2.5', 'UOL Maths Building PM2.5', 'Wavertree PM2.5', 'Widnes Milton Road PM2.5', 'Wirral Tranmere PM2.5']))
plt.ylabel('Frequency')
plt.xlabel('Range')
# Out:
# Text(0.5, 0, 'Range')

# %%
##cannot figure out how to do all on one graph so will try and put them next to eachother

# %%
#horizontally stacked plots for pm 2.5

fig1, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(25, 5))
fig2, (bx1, bx2, bx3, bx4, bx5) = plt.subplots(1, 5, figsize=(25, 5))
fig3, (cx1, cx2, cx3, cx4, cx5) = plt.subplots(1, 5, figsize=(25, 5))
fig4, (dx1, dx2, dx3, dx4, dx5) = plt.subplots(1, 5, figsize=(25, 5))
fig5, (ex1, ex2, ex3, ex4, ex5, ex6) = plt.subplots(1, 6, figsize=(25, 5))
fig1.suptitle('PM2.5 across Liverpool')
ax1.plot(ave_pm2p5aig_hours, 'black')
ax2.plot(ave_pm2p5all_hours, 'grey')
ax3.plot(ave_pm2p5anf_hours, 'rosybrown')
ax4.plot(ave_pm2p5bir_hours, 'lightcoral')
ax5.plot(ave_pm2p5bru_hours, 'brown')
bx1.plot(ave_pm2p5eve_hours, 'red')
bx2.plot(ave_pm2p5gar_hours, 'orangered')
bx3.plot(ave_pm2p5kir_hours, 'sienna')
bx4.plot(ave_pm2p5lif_hours, 'peachpuff')
bx5.plot(ave_pm2p5lpc_hours, 'burlywood')
cx1.plot(ave_pm2p5jmu_hours, 'orange')
cx2.plot(ave_pm2p5hay_hours, 'gold')
cx3.plot(ave_pm2p5osw_hours, 'khaki')
cx4.plot(ave_pm2p5qsq_hours, 'olive')
cx5.plot(ave_pm2p5rox_hours, 'yellow')
dx1.plot(ave_pm2p5spe_hours, 'lawngreen')
dx2.plot(ave_pm2p5sth_hours, 'lime')
dx3.plot(ave_pm2p5nic_hours, 'aquamarine')
dx4.plot(ave_pm2p5sad_hours, 'turquoise')
dx5.plot(ave_pm2p5scp_hours, 'aqua')
ex1.plot(ave_pm2p5uol_hours, 'deepskyblue')
ex2.plot(ave_pm2p5wav_hours, 'royalblue')
ex3.plot(ave_pm2p5wid_hours, 'slateblue')
ex4.plot(ave_pm2p5wil_hours, 'blueviolet')
ex5.plot(ave_pm2p5win_hours, 'fuchsia')
ex6.plot(ave_pm2p5wir_hours, 'pink')

ax1.set(xlabel='Hours', ylabel='PM2.5 concentration (µg/m³)')
ax2.set(xlabel='Hours', ylabel='')
ax3.set(xlabel='Hours', ylabel='')
ax4.set(xlabel='Hours', ylabel='')
ax5.set(xlabel='Hours', ylabel='')
bx1.set(xlabel='Hours', ylabel='PM2.5 concentration (µg/m³)')
bx2.set(xlabel='Hours', ylabel='')
bx3.set(xlabel='Hours', ylabel='')
bx4.set(xlabel='Hours', ylabel='')
bx5.set(xlabel='Hours', ylabel='')
cx1.set(xlabel='Hours', ylabel='PM2.5 concentration (µg/m³)')
cx2.set(xlabel='Hours', ylabel='')
cx3.set(xlabel='Hours', ylabel='')
cx4.set(xlabel='Hours', ylabel='')
cx5.set(xlabel='Hours', ylabel='')
dx1.set(xlabel='Hours', ylabel='PM2.5 concentration (µg/m³)')
dx2.set(xlabel='Hours', ylabel='')
dx3.set(xlabel='Hours', ylabel='')
dx4.set(xlabel='Hours', ylabel='')
dx5.set(xlabel='Hours', ylabel='')
ex1.set(xlabel='Hours', ylabel='PM2.5 concentration (µg/m³)')
ex2.set(xlabel='Hours', ylabel='')
ex3.set(xlabel='Hours', ylabel='')
ex4.set(xlabel='Hours', ylabel='')
ex5.set(xlabel='Hours', ylabel='')
ex6.set(xlabel='Hours', ylabel='')
ax1.set_title("Aigburth station")
ax2.set_title("All Saints Primary School")
ax3.set_title("Anfield")
ax4.set_title("Birkenhead")
ax5.set_title("Brunswick Station")
bx1.set_title("Everton Valley")
bx2.set_title("Garston")
bx3.set_title("Kirkdale Station")
bx4.set_title("Life Sciences Building")
bx5.set_title("Liverpool Central Station")
cx1.set_title("LJMU")
cx2.set_title("Old Haymarket")
cx3.set_title("Old Swan")
cx4.set_title("Queens Square")
cx5.set_title("Roxby Building")
dx1.set_title("Speke")
dx2.set_title("St Helens Linkway")
dx3.set_title("St Nicolas Primary")
dx4.set_title("Strand Albert Dock")
dx5.set_title("Strand Chavasse Park")
ex1.set_title("UOL Maths Building")
ex2.set_title("Wavertree")
ex3.set_title("Widnes Milton Road")
ex4.set_title("Williamson Square")
ex5.set_title("Winchfield Road")
ex6.set_title("Wirral Tranmere")
# Out:
# Text(0.5, 1.0, 'Wirral Tranmere')

# %%
#calculate pollutants throughout the day for pm10 aigburth
ave_pm10aig_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10aig_hours[i] = np.nanmean(pm10aig[datesaig.hour == i])
plt.plot(ave_pm10aig_hours,'blue', label='Aigburth 24-hour average')
plt.legend()
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 all saints
ave_pm10all_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10all_hours[i] = np.nanmean(pm10all[datesall.hour == i])
plt.plot(ave_pm10all_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 anfield 
ave_pm10anf_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10anf_hours[i] = np.nanmean(pm10anf[datesanf.hour == i])
plt.plot(ave_pm10anf_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 birk
ave_pm10bir_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10bir_hours[i] = np.nanmean(pm10bir[datesbir.hour == i])
plt.plot(ave_pm10bir_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice
#   after removing the cwd from sys.path.
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 bruns
ave_pm10bru_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10bru_hours[i] = np.nanmean(pm10bru[datesbru.hour == i])
plt.plot(ave_pm10bru_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some lables
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 eve
ave_pm10eve_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10eve_hours[i] = np.nanmean(pm10eve[dateseve.hour == i])
plt.plot(ave_pm10eve_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 gar
ave_pm10gar_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10gar_hours[i] = np.nanmean(pm10gar[datesgar.hour == i])
plt.plot(ave_pm10gar_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 kirk
ave_pm10kir_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10kir_hours[i] = np.nanmean(pm10kir[dateskir.hour == i])
plt.plot(ave_pm10kir_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 life
ave_pm10lif_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10lif_hours[i] = np.nanmean(pm10lif[dateslif.hour == i])
plt.plot(ave_pm10lif_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 lpc
ave_pm10lpc_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10lpc_hours[i] = np.nanmean(pm10lpc[dateslpc.hour == i])
plt.plot(ave_pm10lpc_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 LJUM
ave_pm10jmu_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10jmu_hours[i] = np.nanmean(pm10jmu[datesjmu.hour == i])
plt.plot(ave_pm10jmu_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some lables
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 haymarket
ave_pm10hay_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10hay_hours[i] = np.nanmean(pm10hay[dateshay.hour == i])
plt.plot(ave_pm10hay_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 swan
ave_pm10osw_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10osw_hours[i] = np.nanmean(pm10osw[datesosw.hour == i])
plt.plot(ave_pm10osw_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 queen
ave_pm10qsq_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10qsq_hours[i] = np.nanmean(pm10qsq[datesqsq.hour == i])
plt.plot(ave_pm10qsq_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 roxby
ave_pm10rox_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10rox_hours[i] = np.nanmean(pm10rox[datesrox.hour == i])
plt.plot(ave_pm10rox_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 speke
ave_pm10spe_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10spe_hours[i] = np.nanmean(pm10spe[datesspe.hour == i])
plt.plot(ave_pm10spe_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 st helens
ave_pm10sth_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10sth_hours[i] = np.nanmean(pm10sth[datessth.hour == i])
plt.plot(ave_pm10sth_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 st nics
ave_pm10nic_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10nic_hours[i] = np.nanmean(pm10nic[datesnic.hour == i])
plt.plot(ave_pm10nic_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 strand albert
ave_pm10sad_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10sad_hours[i] = np.nanmean(pm10sad[datessad.hour == i])
plt.plot(ave_pm10sad_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 strand park
ave_pm10scp_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10scp_hours[i] = np.nanmean(pm10scp[datesscp.hour == i])
plt.plot(ave_pm10scp_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 uol maths
ave_pm10uol_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10uol_hours[i] = np.nanmean(pm10uol[datesuol.hour == i])
plt.plot(ave_pm10uol_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 waver

ave_pm10wav_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10wav_hours[i] = np.nanmean(pm10wav[dateswav.hour == i])
plt.plot(ave_pm10wav_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 widnes
ave_pm10wid_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10wid_hours[i] = np.nanmean(pm10wid[dateswid.hour == i])
plt.plot(ave_pm10wid_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice
#   after removing the cwd from sys.path.
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 williamson
ave_pm10wil_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10wil_hours[i] = np.nanmean(pm10wil[dateswil.hour == i])
plt.plot(ave_pm10wil_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 winchfield
ave_pm10win_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10wil_hours[i] = np.nanmean(pm10wil[dateswil.hour == i])
plt.plot(ave_pm10wil_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#calculate pollutants throughout the day for pm10 wirral
ave_pm10wir_hours = np.zeros([24,])
for i in range (0,24):
  ave_pm10wir_hours[i] = np.nanmean(pm10wir[dateswir.hour == i])
plt.plot(ave_pm10wir_hours,'blue')
plt.ylabel('Hourly average PM2.5 concentration (µg/m³)') # add some labels
plt.xlabel('Hours') # add some labels
# Out:
# Text(0.5, 0, 'Hours')

# %%
#horizontally stacked plots for pm 10

fig1, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(25, 5))
fig2, (bx1, bx2, bx3, bx4, bx5) = plt.subplots(1, 5, figsize=(25, 5))
fig3, (cx1, cx2, cx3, cx4, cx5) = plt.subplots(1, 5, figsize=(25, 5))
fig4, (dx1, dx2, dx3, dx4, dx5) = plt.subplots(1, 5, figsize=(25, 5))
fig5, (ex1, ex2, ex3, ex4, ex5, ex6) = plt.subplots(1, 6, figsize=(25, 5))
fig1.suptitle('PM10 across Liverpool')
ax1.plot(ave_pm10aig_hours, 'black')
ax2.plot(ave_pm10all_hours, 'grey')
ax3.plot(ave_pm10anf_hours, 'rosybrown')
ax4.plot(ave_pm10bir_hours, 'lightcoral')
ax5.plot(ave_pm10bru_hours, 'brown')
bx1.plot(ave_pm10eve_hours, 'red')
bx2.plot(ave_pm10gar_hours, 'orangered')
bx3.plot(ave_pm10kir_hours, 'sienna')
bx4.plot(ave_pm10lif_hours, 'peachpuff')
bx5.plot(ave_pm10lpc_hours, 'burlywood')
cx1.plot(ave_pm10jmu_hours, 'orange')
cx2.plot(ave_pm10hay_hours, 'gold')
cx3.plot(ave_pm10osw_hours, 'khaki')
cx4.plot(ave_pm10qsq_hours, 'olive')
cx5.plot(ave_pm10rox_hours, 'yellow')
dx1.plot(ave_pm10spe_hours, 'lawngreen')
dx2.plot(ave_pm10sth_hours, 'lime')
dx3.plot(ave_pm10nic_hours, 'aquamarine')
dx4.plot(ave_pm10sad_hours, 'turquoise')
dx5.plot(ave_pm10scp_hours, 'aqua')
ex1.plot(ave_pm10uol_hours, 'deepskyblue')
ex2.plot(ave_pm10wav_hours, 'royalblue')
ex3.plot(ave_pm10wid_hours, 'slateblue')
ex4.plot(ave_pm10wil_hours, 'blueviolet')
ex5.plot(ave_pm10win_hours, 'fuchsia')
ex6.plot(ave_pm10wir_hours, 'pink')

ax1.set(xlabel='Hours', ylabel='PM10 concentration (µg/m³)')
ax2.set(xlabel='Hours', ylabel='')
ax3.set(xlabel='Hours', ylabel='')
ax4.set(xlabel='Hours', ylabel='')
ax5.set(xlabel='Hours', ylabel='')
bx1.set(xlabel='Hours', ylabel='PM10 concentration (µg/m³)')
bx2.set(xlabel='Hours', ylabel='')
bx3.set(xlabel='Hours', ylabel='')
bx4.set(xlabel='Hours', ylabel='')
bx5.set(xlabel='Hours', ylabel='')
cx1.set(xlabel='Hours', ylabel='PM10 concentration (µg/m³)')
cx2.set(xlabel='Hours', ylabel='')
cx3.set(xlabel='Hours', ylabel='')
cx4.set(xlabel='Hours', ylabel='')
cx5.set(xlabel='Hours', ylabel='')
dx1.set(xlabel='Hours', ylabel='PM10 concentration (µg/m³)')
dx2.set(xlabel='Hours', ylabel='')
dx3.set(xlabel='Hours', ylabel='')
dx4.set(xlabel='Hours', ylabel='')
dx5.set(xlabel='Hours', ylabel='')
ex1.set(xlabel='Hours', ylabel='PM10 concentration (µg/m³)')
ex2.set(xlabel='Hours', ylabel='')
ex3.set(xlabel='Hours', ylabel='')
ex4.set(xlabel='Hours', ylabel='')
ex5.set(xlabel='Hours', ylabel='')
ex6.set(xlabel='Hours', ylabel='')
ax1.set_title("Aigburth station")
ax2.set_title("All Saints Primary School")
ax3.set_title("Anfield")
ax4.set_title("Birkenhead")
ax5.set_title("Brunswick Station")
bx1.set_title("Everton Valley")
bx2.set_title("Garston")
bx3.set_title("Kirkdale Station")
bx4.set_title("Life Sciences Building")
bx5.set_title("Liverpool Central Station")
cx1.set_title("LJMU")
cx2.set_title("Old Haymarket")
cx3.set_title("Old Swan")
cx4.set_title("Queens Square")
cx5.set_title("Roxby Building")
dx1.set_title("Speke")
dx2.set_title("St Helens Linkway")
dx3.set_title("St Nicolas Primary")
dx4.set_title("Strand Albert Dock")
dx5.set_title("Strand Chavasse Park")
ex1.set_title("UOL Maths Building")
ex2.set_title("Wavertree")
ex3.set_title("Widnes Milton Road")
ex4.set_title("Williamson Square")
ex5.set_title("Winchfield Road")
ex6.set_title("Wirral Tranmere")
# Out:
# Text(0.5, 1.0, 'Wirral Tranmere')

# %%
#calculate pollutants throughout the week for pm2.5 aigburth
ave_pm2p5aig_days = np.zeros([7,])
for i in range (0,7):
  ave_pm2p5aig_days[i] = np.nanmean(pm2p5aig[datesaig.day_of_week == i])
plt.plot(ave_pm2p5aig_days)

# %%
#calculate pollutants throughout the week for pm2.5 aigburth
ave_pm2p5aig_days = np.zeros([7,])
for i in range (0,7):
  ave_pm2p5aig_days[i] = np.nanmean(pm2p5aig[datesaig.day_of_week == i])
plt.plot(ave_pm2p5aig_days)
plt.tick_params(labelbottom=False)
